# %% [markdown]
# # 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %% [markdown]
# These files will be opened in binary mode.,read binary (rb) for PdfFileREader() and write binary (wb) PdfFileWriter()

# %%
# !pip install pyPDF2
# Out:
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=7c7df0a498b76504f72edb7d0fd769cf0ff32c540a34dd586df9ecb3b51c85f5
#   Stored in directory: c:\users\370011617\appdata\local\pip\cache\wheels\d9\dc\ec\72da68331f30074b9950c1737c23cb8a67484e61498bc9713d
# Successfully built PyPDF2
# ...

# %% [markdown]
# # 2. From a PdfFileReader object, how do you get a Page object for page 5?

# %% [markdown]
# Calling getPage(4) will return a page object for page 5 since page 0 is the first page.

# %%
import PyPDF2

# %%
import PyPDF2 as pdf
pdfFileObj=open("LeanSixSigma.pdf","rb")
pdfReader=pdf.PdfFileReader(pdfFileObj)
pageObj=pdfReader.getPage(4)
pageObj.extractText()
# Out:
# 'Lean Transformation \n\n \nA complete \ntransformation \nhand book\n \n________________________________\n___________________________\n \n \n \nACKNOWLEDGMENTS\n \n \nNo person operates in vacuum. I have been the beneficiary of \nthe wisdom of many people over the years. It was no less true \nduring the creation of this book. My well wishe\nr an\nd partner \npatiently kept my feet\n \no\nn\n \nthe ground whenever I began to stray \nfrom reality. My Father, Kamendu  & Mother, Ramila always be \nsource of inspiration \nin my career, achieving the goals and \nwriting the book. My wife Grishma and daughter Shveni sing\nle \nhandedly kept our life together regardless of where my head \nwas at any point of time. Thank you all for your support and \nbelief in me.\n \nMy successful career in this field is the result of an accumulation \nof both knowledge and experience.  I would like to\n \nacknowledge \nthe opportunity and experience gain during my association with \nall esteemed organizati
# ...

# %% [markdown]
# # 3. What PdfFileReader variable stores the number of pages in the PDF document?

# %% [markdown]
# The pdfFileReader.numPages variable stores an integer of the number of pages in the pdfFileReader object

# %%
import PyPDF2 as pdf
pdfFileObj = open("LeanSixSigma.pdf",'rb')
pdfReader = pdf.PdfFileReader(pdfFileObj)
pdfReader.numPages
# Out:
# 160

# %% [markdown]
# # 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %% [markdown]
# Before we obtain the page object, the pdf has to be decrypted by calling .decrypted('swordfish')

# %% [raw]
# pdfReader.decrypt('swordfish')

# %% [markdown]
# # 5. What methods do you use to rotate a page?

# %% [markdown]
# The rotateClockwise() and rotateCounterClockwise() methods. The Degrees to rotate is passed as an integer argument

# %%
pageObj.rotateClockwise(180)
# Out:
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 160,
#   '/Kids': [IndirectObject(3, 0),
#    IndirectObject(7, 0),
#    IndirectObject(28, 0),
#    IndirectObject(30, 0),
#    IndirectObject(34, 0),
#    IndirectObject(36, 0),
#    IndirectObject(38, 0),
#    IndirectObject(40, 0),
#    IndirectObject(42, 0),
#    IndirectObject(44, 0),
#    IndirectObject(46, 0),
#    IndirectObject(51, 0),
#    IndirectObject(58, 0),
#    IndirectObject(61, 0),
#    IndirectObject(70, 0),
#    IndirectObject(77, 0),
#    IndirectObject(79, 0),
#    IndirectObject(81, 0),
#    IndirectObject(88, 0),
#    IndirectObject(94, 0),
#    IndirectObject(96, 0),
#    IndirectObject(98, 0),
#    IndirectObject(104, 0),
#    IndirectObject(107, 0),
#    IndirectObject(114, 0),
#    IndirectObject(116, 0),
#    IndirectObject(119, 0),
#    IndirectObject(121, 0),
#    IndirectObject(123, 0),
#    IndirectObject(125, 0),
#    IndirectObject(127, 0),
#    IndirectObject(129, 0),
# ...

# %% [markdown]
# # 6. What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# Paragraph Object:
#
#     A document contains multiple paragraphs. A paragraphs begins on a new line and contains multiple runs.
#
#     The Document object contains a list of paragraphs objects for the paragraphs in the document. (A new paragraph begins whenever the user presses ENTER or RETURN while typing in a word document.)
#
# Run Objects:
#
#     Runs are contiguous groups of characters within a paragraph with the same style

# %% [markdown]
# # 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

# %% [markdown]
# By using doc.paragraphs

# %%
# !pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=6631c53e113b7e2553c24e4fed44ce383d217ce88bcefbcee4fb40c476425171
#   Stored in directory: c:\users\370011617\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...

# %%
import docx
doc=docx.Document('Assignment_1.docx')
doc.paragraphs

# %% [markdown]
# # 8. What type of object has bold, underline, italic, strike, and outline variables?

# %% [markdown]
# A Run object has bold, underline,italic,strike and outline variables

# %% [markdown]
# # 9. What is the difference between False, True, and None for the bold variable?

# %% [markdown]
# Runs can be further styled using text attributes. each attribute can be set to one of three values:
#
#     True: The attributes is always enabled, no matter what other styles are applied to the run.
#
#     False: The atrribute is always disabled
#
#     None: defaults to whatever the runs style is set to.
#
# True always makes the run object bolded and False makes it always not bolded, No matter what the styles bold setting is.
#
# None will make the Run object just use the styles bold setting.

# %% [markdown]
# # 10. How do you create a Document object for a new Word document?

# %% [markdown]
# By calling the docx.Document() function

# %% [markdown]
# # 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

# %%
import docx
doc=docx.Document()

doc.add_paragraph('Hello there!')
doc.save('hellothere.docx')

# %% [markdown]
# # 12. What integers represent the levels of headings available in Word documents?

# %% [markdown]
# Integer from 0 to 4
#
# The arguments to add_heading() are a string of the heading text and an integer from 0 to 4. The integer 0 makes the heading the Title style, which is used for the top of the document. Integers 1 to 4 are for various heading levels, with 1 being the main heading and 4 is the lowest subheading
